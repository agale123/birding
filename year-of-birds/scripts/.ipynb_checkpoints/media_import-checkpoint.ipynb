# %%
import requests
import time
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv("../raw/media.csv")
df
# Out:
#      ML Catalog Number Format         Common Name          Scientific Name  \
# 0            663312703  Photo        Sooty Grouse  Dendragapus fuliginosus
# 1            663312702  Photo        Sooty Grouse  Dendragapus fuliginosus
# 2            663312704  Photo        Sooty Grouse  Dendragapus fuliginosus
# 3            663312701  Photo        Sooty Grouse  Dendragapus fuliginosus
# 4            663312672  Photo  Northern Pygmy-Owl         Glaucidium gnoma
# ..                 ...    ...                 ...                      ...
# 630          648016433  Photo            Killdeer     Charadrius vociferus
# 631          648016413  Photo       American Coot         Fulica americana
# 632          648016389  Photo           Wood Duck               Aix sponsa
# 633          648016397  Photo             Gadwall          Mareca strepera
# 634          648016390  Photo           Wood Duck               Aix sponsa
#
# ...

# %%
df = df[[
    "ML Catalog Number",
    "Common Name",
    "Scientific Name",
    "Date",
    "Time",
    "Country",
    "State",
    "County",
    "Locality",
    "Latitude",
    "Longitude",
    "eBird Checklist ID"
]]
df
# Out:
#      ML Catalog Number         Common Name          Scientific Name  \
# 0            663312703        Sooty Grouse  Dendragapus fuliginosus
# 1            663312702        Sooty Grouse  Dendragapus fuliginosus
# 2            663312704        Sooty Grouse  Dendragapus fuliginosus
# 3            663312701        Sooty Grouse  Dendragapus fuliginosus
# 4            663312672  Northern Pygmy-Owl         Glaucidium gnoma
# ..                 ...                 ...                      ...
# 630          648016433            Killdeer     Charadrius vociferus
# 631          648016413       American Coot         Fulica americana
# 632          648016389           Wood Duck               Aix sponsa
# 633          648016397             Gadwall          Mareca strepera
# 634          648016390           Wood Duck               Aix sponsa
#
#            Date  Time        Country       State  County  \
# 0    2026-08-17  1700  United States  Washington  Pierce
# ...

# %%
def download_image(image_id):
    url = "https://macaulaylibrary.org/internal/v1/original-url/" + image_id

    custom_headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36",
        "Accept": "application/json, text/plain, */*",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "en-US,en;q=0.9,sv;q=0.8",
        # Update this cookie to run successfully
        "Cookie": "_gcl_au=1.1.1256505712.1785719621; _ga=GA1.1.138661537.1785719621; hubspotutk=099c9ce26e927bf91d5bf973bcb36008; _ga_YT7Y2S4MBX=GS2.1.s1785719620$o1$g0$t1785719624$j56$l0$h0; I18N_LANGUAGE=en; _14dd1=893b47d3f72ea5cc; macaulaylibrary.org-anubis-cookie-verification=01a020e2-19fb-7cd1-8145-014ed5054641; macaulaylibrary.org-anubis-auth=eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9..J3gILrxMu3a6IuOv7ZnXayuRggsMTOxapcsY061nKqmcPkOxZ0KmGeWoAuvHsWuHsDuWTRkaGlf3okwhnSu0AQ; __hstc=264660688.099c9ce26e927bf91d5bf973bcb36008.1785719621834.1786283198421.1787258088566.3; __hssrc=1; ml-search-session=...; ml-search-session.sig=6CDiX76pmTTU-GdSgqhTpsyZlRI; _ga_CYH8S0R99B=GS2.1.s1787258087$o3$g1$t1787258106$j41$l0$h0; _ga_QR4NVXZ8BM=GS2.1.s1787258087$o3$g1$t1787258106$j41$l0$h1407459820; _ga_DTHTPXK4V9=GS2.1.s1787258087$o3$g1$t1787258106$j41$l0$h0; __hssc=264660688.2.1787258088566",
        "Priority": "u=1, i",
        "Referer": "https://macaulaylibrary.org/asset/" + image_id
    }

    with requests.get(url, headers=custom_headers, stream=True) as response:
        img_data = requests.get(response.text).content
        with open("../images/" + image_id + ".jpg", 'wb') as handler:
            handler.write(img_data)

# %%
for index, row in df.iterrows():
    image_id = str(row["ML Catalog Number"])
    file_path = Path("../images/" + image_id + ".jpg")
    if file_path.is_file():
        print("Skipping " + image_id)
        continue
    time.sleep(2)
    download_image(image_id)
# Out:
# Skipping 662621240
# Skipping 662621237
# Skipping 662621238
# Skipping 662621239
# Skipping 662621227
# Skipping 662621228
# Skipping 662621216
# Skipping 662621212
# Skipping 662621211
# Skipping 662621207
# Skipping 662621204
# Skipping 662526261
# Skipping 662526259
# Skipping 662526255
# Skipping 662526254
# Skipping 662526250
# Skipping 662363419
# Skipping 662363381
# Skipping 662363380
# Skipping 662363377
# Skipping 662363378
# Skipping 662363358
# Skipping 662363351
# Skipping 662363344
# Skipping 662363343
# Skipping 662363337
# Skipping 662363331
# Skipping 662363332
# Skipping 662363326
# Skipping 662363325
# Skipping 662363324
# Skipping 662363313
# Skipping 662363311
# Skipping 662363307
# Skipping 662363306
# Skipping 662363299
# Skipping 662359436
# Skipping 662359430
# Skipping 662359429
# Skipping 662359427
# Skipping 662145476
# Skipping 662145463
# Skipping 662145464
# Skipping 661835303
# Skipping 661835278
# Skipping 661835274
# Skipping 661835275
# ...
